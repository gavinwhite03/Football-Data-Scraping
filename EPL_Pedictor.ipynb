# %%
import pandas as pd

# %%
matches = pd.read_csv("Predicting EPL Games/matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# 1    2022  Manchester City
# 2    2022  Manchester City
# 3    2022  Manchester City
# 4    2022  Manchester City
# 6    2022  Manchester City
#
# [5 rows x 27 columns]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'venue_code', 'opp_code', 'hour',
#        'day_code'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

# %%
formation_column = 'formation'
label_encoder = LabelEncoder()

# %%
matches['formation_encoded'] = label_encoder.fit_transform(matches[formation_column])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches.dtypes
# Out:
# date                 datetime64[ns]
# time                         object
# comp                         object
# round                        object
# day                          object
# venue                        object
# result                       object
# gf                          float64
# ga                          float64
# opponent                     object
# xg                          float64
# xga                         float64
# poss                        float64
# attendance                  float64
# captain                      object
# formation                    object
# referee                      object
# match report                 object
# notes                       float64
# sh                          float64
# sot                         float64
# dist                        float64
# fk                          float64
# pk                          float64
# pkatt                       float64
# season                        int64
# team                         object
# venue_code                     int8
# opp_code                       int8
# hour                          int32
# day_code                      int32
# formation_encoded             int32
# target                        int32
# dtype: object

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=100, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code", "formation_encoded"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=200, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
acc = accuracy_score(test["target"], preds)

# %%
acc
# Out:
# 0.6195652173913043

# %%
combined = pd.DataFrame(dict(actual=test["target"], prediction=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["prediction"])
# Out:
# prediction    0   1
# actual
# 0           143  29
# 1            76  28

# %%
from sklearn.metrics import precision_score

# %%
precision = precision_score(test["target"], preds)

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City")

# %%
group
# Out:
#          date   time            comp         round  day venue result   gf  \
# 1  2021-08-15  16:30  Premier League   Matchweek 1  Sun  Away      L  0.0
# 2  2021-08-21  15:00  Premier League   Matchweek 2  Sat  Home      W  5.0
# 3  2021-08-28  12:30  Premier League   Matchweek 3  Sat  Home      W  5.0
# 4  2021-09-11  15:00  Premier League   Matchweek 4  Sat  Away      W  1.0
# 6  2021-09-18  15:00  Premier League   Matchweek 5  Sat  Home      D  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 54 2021-05-01  12:30  Premier League  Matchweek 34  Sat  Away      W  2.0
# 56 2021-05-08  17:30  Premier League  Matchweek 35  Sat  Home      L  1.0
# 57 2021-05-14  20:00  Premier League  Matchweek 36  Fri  Away      W  4.0
# 58 2021-05-18  19:00  Premier League  Matchweek 37  Tue  Away      L  2.0
# 59 2021-05-23  16:00  Premier League  Matchweek 38  Sun  Home      W  5.0
#
#      ga        opponent  ...   pk  pkatt  season             team venue_code  \
# 1   1.0       Tottenham  ...  0.0    0.0    2022  Manchester City          0
# 2   0.0    Norwich City  ...  0.0    0.0    2022  Manchester City          1
# 3   0.0         Arsenal  ...  0.0    0.0    2022  Manchester City          1
# 4   0.0  Leicester City  ...  0.0    0.0    2022  Manchester City          0
# 6   0.0     Southampton  ...  0.0    0.0    2022  Manchester City          1
# ..  ...             ...  ...  ...    ...     ...              ...        ...
# 54  0.0  Crystal Palace  ...  0.0    0.0    2021  Manchester City          0
# 56  2.0         Chelsea  ...  0.0    1.0    2021  Manchester City          1
# 57  3.0   Newcastle Utd  ...  0.0    0.0    2021  Manchester City          0
# 58  3.0        Brighton  ...  0.0    0.0    2021  Manchester City          0
# 59  0.0         Everton  ...  0.0    0.0    2021  Manchester City          1
#
#    opp_code hour day_code  formation_encoded  target
# 1        18   16        6                 10       0
# 2        15   15        5                 10       1
# 3         0   12        5                 10       1
# 4        10   15        5                 10       1
# 6        17   15        5                 10       0
# ..      ...  ...      ...                ...     ...
# 54        6   12        5                 12       1
# 56        5   17        5                  4       0
# 57       14   20        4                 10       1
# 58        3   19        1                 10       0
# 59        7   16        6                 10       1
#
# [71 rows x 33 columns]

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
matches.dtypes
# Out:
# date                 datetime64[ns]
# time                         object
# comp                         object
# round                        object
# day                          object
# venue                        object
# result                       object
# gf                          float64
# ga                          float64
# opponent                     object
# xg                          float64
# xga                         float64
# poss                        float64
# attendance                  float64
# captain                      object
# formation                    object
# referee                      object
# match report                 object
# notes                       float64
# sh                          float64
# sot                         float64
# dist                        float64
# fk                          float64
# pk                          float64
# pkatt                       float64
# season                        int64
# team                         object
# venue_code                     int8
# opp_code                       int8
# hour                          int32
# day_code                      int32
# formation_encoded             int32
# target                        int32
# dtype: object

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt", "xg", "xga"]
new_cols = [f"{c}_rolling" for c in cols]

# %%
new_cols
# Out:
# ['gf_rolling',
#  'ga_rolling',
#  'sh_rolling',
#  'sot_rolling',
#  'dist_rolling',
#  'fk_rolling',
#  'pk_rolling',
#  'pkatt_rolling',
#  'xg_rolling',
#  'xga_rolling']

# %%
rolling_averages(group, cols, new_cols)
# Out:
#          date   time            comp         round  day venue result   gf  \
# 5  2020-10-17  17:30  Premier League   Matchweek 5  Sat  Home      W  1.0
# 7  2020-10-24  12:30  Premier League   Matchweek 6  Sat  Away      D  1.0
# 9  2020-10-31  12:30  Premier League   Matchweek 7  Sat  Away      W  1.0
# 11 2020-11-08  16:30  Premier League   Matchweek 8  Sun  Home      D  1.0
# 12 2020-11-21  17:30  Premier League   Matchweek 9  Sat  Away      L  0.0
# ..        ...    ...             ...           ...  ...   ...    ...  ...
# 42 2022-03-14  20:00  Premier League  Matchweek 29  Mon  Away      D  0.0
# 44 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Away      W  2.0
# 46 2022-04-10  16:30  Premier League  Matchweek 32  Sun  Home      D  2.0
# 49 2022-04-20  20:00  Premier League  Matchweek 30  Wed  Home      W  3.0
# 50 2022-04-23  15:00  Premier League  Matchweek 34  Sat  Home      W  5.0
#
#      ga        opponent  ...  gf_rolling  ga_rolling  sh_rolling  sot_rolling  \
# 5   0.0         Arsenal  ...    2.000000    2.333333   17.333333     4.666667
# 7   1.0        West Ham  ...    1.333333    2.000000   17.333333     3.666667
# 9   0.0   Sheffield Utd  ...    1.000000    0.666667   16.666667     4.333333
# 11  1.0       Liverpool  ...    1.000000    0.333333   14.333333     6.666667
# 12  2.0       Tottenham  ...    1.000000    0.666667   12.000000     5.666667
# ..  ...             ...  ...         ...         ...         ...          ...
# 42  0.0  Crystal Palace  ...    2.333333    1.333333   19.000000     7.000000
# 44  0.0         Burnley  ...    1.666667    0.333333   18.333333     7.333333
# 46  2.0       Liverpool  ...    2.000000    0.333333   20.000000     6.666667
# 49  0.0        Brighton  ...    1.333333    0.666667   15.666667     4.666667
# 50  1.0         Watford  ...    2.333333    0.666667   15.333333     5.000000
#
#    dist_rolling fk_rolling pk_rolling pkatt_rolling  xg_rolling  xga_rolling
# 5     18.900000   1.333333   0.333333      0.333333    1.433333     1.766667
# 7     17.733333   0.666667   0.000000      0.000000    1.300000     1.733333
# 9     18.233333   0.666667   0.000000      0.000000    1.366667     1.033333
# 11    18.466667   1.000000   0.000000      0.000000    1.366667     0.633333
# 12    19.366667   1.000000   0.000000      0.333333    1.400000     0.800000
# ..          ...        ...        ...           ...         ...          ...
# 42    15.366667   0.333333   0.333333      0.333333    2.100000     1.033333
# 44    16.000000   0.333333   0.000000      0.000000    2.166667     0.700000
# 46    16.133333   0.333333   0.000000      0.000000    2.233333     0.466667
# 49    16.700000   0.333333   0.000000      0.000000    2.033333     0.633333
# 50    17.200000   0.333333   0.000000      0.000000    1.666667     0.400000
#
# [68 rows x 43 columns]

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))
# Out:
# C:\Users\anoth\AppData\Local\Temp\ipykernel_19020\4052147919.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time            comp         round  \
# team
# Arsenal                 6  2020-10-04  14:00  Premier League   Matchweek 4
#                         7  2020-10-17  17:30  Premier League   Matchweek 5
#                         9  2020-10-25  19:15  Premier League   Matchweek 6
#                         11 2020-11-01  16:30  Premier League   Matchweek 7
#                         13 2020-11-08  19:15  Premier League   Matchweek 8
# ...                               ...    ...             ...           ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Premier League  Matchweek 29
#                         33 2022-03-18  20:00  Premier League  Matchweek 30
#                         34 2022-04-02  15:00  Premier League  Matchweek 31
#                         35 2022-04-08  20:00  Premier League  Matchweek 32
#                         36 2022-04-24  14:00  Premier League  Matchweek 34
#
#                             day venue result   gf   ga         opponent  ...  \
# team                                                                     ...
# Arsenal                 6   Sun  Home      W  2.0  1.0    Sheffield Utd  ...
#                         7   Sat  Away      L  0.0  1.0  Manchester City  ...
#                         9   Sun  Home      L  0.0  1.0   Leicester City  ...
#                         11  Sun  Away      W  1.0  0.0   Manchester Utd  ...
#                         13  Sun  Home      L  0.0  3.0      Aston Villa  ...
# ...                         ...   ...    ...  ...  ...              ...  ...
# Wolverhampton Wanderers 32  Sun  Away      W  1.0  0.0          Everton  ...
#                         33  Fri  Home      L  2.0  3.0     Leeds United  ...
#                         34  Sat  Home      W  2.0  1.0      Aston Villa  ...
#                         35  Fri  Away      L  0.0  1.0    Newcastle Utd  ...
#                         36  Sun  Away      L  0.0  1.0          Burnley  ...
#
#                             gf_rolling  ga_rolling  sh_rolling  sot_rolling  \
# team
# Arsenal                 6     2.000000    1.333333    7.666667     3.666667
#                         7     1.666667    1.666667    5.333333     3.666667
#                         9     1.000000    1.666667    7.000000     3.666667
#                         11    0.666667    1.000000    9.666667     4.000000
#                         13    0.333333    0.666667    9.666667     2.666667
# ...                                ...         ...         ...          ...
# Wolverhampton Wanderers 32    1.333333    1.000000   12.333333     3.666667
#                         33    1.666667    0.666667   12.333333     4.333333
#                         34    2.333333    1.000000   13.000000     5.333333
#                         35    1.666667    1.333333   13.000000     5.000000
#                         36    1.333333    1.666667   10.000000     4.666667
#
#                            dist_rolling fk_rolling pk_rolling pkatt_rolling  \
# team
# Arsenal                 6     14.733333   0.666667   0.000000      0.000000
#                         7     15.766667   0.000000   0.000000      0.000000
#                         9     16.733333   0.666667   0.000000      0.000000
#                         11    16.033333   1.000000   0.000000      0.000000
#                         13    18.033333   1.000000   0.333333      0.333333
# ...                                 ...        ...        ...           ...
# Wolverhampton Wanderers 32    19.300000   0.000000   0.000000      0.000000
#                         33    19.600000   0.000000   0.000000      0.000000
#                         34    19.833333   0.000000   0.000000      0.000000
#                         35    18.533333   0.000000   0.000000      0.000000
#                         36    17.633333   0.000000   0.000000      0.000000
#
#                             xg_rolling  xga_rolling
# team
# Arsenal                 6     1.466667     1.766667
#                         7     1.000000     1.766667
#                         9     0.833333     1.633333
#                         11    0.733333     0.966667
#                         13    0.966667     1.000000
# ...                                ...          ...
# Wolverhampton Wanderers 32    0.733333     1.866667
#                         33    0.733333     1.333333
#                         34    0.833333     1.200000
#                         35    0.933333     1.600000
#                         36    0.766667     1.966667
#
# [1317 rows x 43 columns]

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
matches_rolling
# Out:
#            date   time            comp         round  day venue result   gf  \
# 0    2020-10-04  14:00  Premier League   Matchweek 4  Sun  Home      W  2.0
# 1    2020-10-17  17:30  Premier League   Matchweek 5  Sat  Away      L  0.0
# 2    2020-10-25  19:15  Premier League   Matchweek 6  Sun  Home      L  0.0
# 3    2020-11-01  16:30  Premier League   Matchweek 7  Sun  Away      W  1.0
# 4    2020-11-08  19:15  Premier League   Matchweek 8  Sun  Home      L  0.0
# ...         ...    ...             ...           ...  ...   ...    ...  ...
# 1312 2022-03-13  14:00  Premier League  Matchweek 29  Sun  Away      W  1.0
# 1313 2022-03-18  20:00  Premier League  Matchweek 30  Fri  Home      L  2.0
# 1314 2022-04-02  15:00  Premier League  Matchweek 31  Sat  Home      W  2.0
# 1315 2022-04-08  20:00  Premier League  Matchweek 32  Fri  Away      L  0.0
# 1316 2022-04-24  14:00  Premier League  Matchweek 34  Sun  Away      L  0.0
#
#        ga         opponent  ...  gf_rolling  ga_rolling  sh_rolling  \
# 0     1.0    Sheffield Utd  ...    2.000000    1.333333    7.666667
# 1     1.0  Manchester City  ...    1.666667    1.666667    5.333333
# 2     1.0   Leicester City  ...    1.000000    1.666667    7.000000
# 3     0.0   Manchester Utd  ...    0.666667    1.000000    9.666667
# 4     3.0      Aston Villa  ...    0.333333    0.666667    9.666667
# ...   ...              ...  ...         ...         ...         ...
# 1312  0.0          Everton  ...    1.333333    1.000000   12.333333
# 1313  3.0     Leeds United  ...    1.666667    0.666667   12.333333
# 1314  1.0      Aston Villa  ...    2.333333    1.000000   13.000000
# 1315  1.0    Newcastle Utd  ...    1.666667    1.333333   13.000000
# 1316  1.0          Burnley  ...    1.333333    1.666667   10.000000
#
#       sot_rolling dist_rolling fk_rolling pk_rolling pkatt_rolling  \
# 0        3.666667    14.733333   0.666667   0.000000      0.000000
# 1        3.666667    15.766667   0.000000   0.000000      0.000000
# 2        3.666667    16.733333   0.666667   0.000000      0.000000
# 3        4.000000    16.033333   1.000000   0.000000      0.000000
# 4        2.666667    18.033333   1.000000   0.333333      0.333333
# ...           ...          ...        ...        ...           ...
# 1312     3.666667    19.300000   0.000000   0.000000      0.000000
# 1313     4.333333    19.600000   0.000000   0.000000      0.000000
# 1314     5.333333    19.833333   0.000000   0.000000      0.000000
# 1315     5.000000    18.533333   0.000000   0.000000      0.000000
# 1316     4.666667    17.633333   0.000000   0.000000      0.000000
#
#       xg_rolling  xga_rolling
# 0       1.466667     1.766667
# 1       1.000000     1.766667
# 2       0.833333     1.633333
# 3       0.733333     0.966667
# 4       0.966667     1.000000
# ...          ...          ...
# 1312    0.733333     1.866667
# 1313    0.733333     1.333333
# 1314    0.833333     1.200000
# 1315    0.933333     1.600000
# 1316    0.766667     1.966667
#
# [1317 rows x 43 columns]

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], prediction=preds), index=test.index)
    precision = precision_score(test["target"], preds)
    return combined, precision

# %%
test.columns
# Out:
# Index(['date', 'time', 'comp', 'round', 'day', 'venue', 'result', 'gf', 'ga',
#        'opponent', 'xg', 'xga', 'poss', 'attendance', 'captain', 'formation',
#        'referee', 'match report', 'notes', 'sh', 'sot', 'dist', 'fk', 'pk',
#        'pkatt', 'season', 'team', 'venue_code', 'opp_code', 'hour', 'day_code',
#        'formation_encoded', 'target'],
#       dtype='object')

# %%
combined, precision = make_predictions(matches_rolling, predictors + new_cols)

# %%
precision
# Out:
# 0.6521739130434783

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined
# Out:
#       actual  prediction       date                     team       opponent  \
# 55         0           0 2022-01-23                  Arsenal        Burnley
# 56         1           1 2022-02-10                  Arsenal         Wolves
# 57         1           0 2022-02-19                  Arsenal      Brentford
# 58         1           1 2022-02-24                  Arsenal         Wolves
# 59         1           1 2022-03-06                  Arsenal        Watford
# ...      ...         ...        ...                      ...            ...
# 1312       1           0 2022-03-13  Wolverhampton Wanderers        Everton
# 1313       0           0 2022-03-18  Wolverhampton Wanderers   Leeds United
# 1314       1           0 2022-04-02  Wolverhampton Wanderers    Aston Villa
# 1315       0           0 2022-04-08  Wolverhampton Wanderers  Newcastle Utd
# 1316       0           0 2022-04-24  Wolverhampton Wanderers        Burnley
#
#      result
# 55        D
# 56        W
# 57        W
# 58        W
# 59        W
# ...     ...
# 1312      W
# 1313      L
# 1314      W
# 1315      L
# 1316      L
#
# [276 rows x 6 columns]

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {
    "Brighton and Hove Albion": "Brighton",
    "Manchester United": "Manchester Utd",
    "Newcastle United": "Newcastle Utd",
    "Tottenham Hotspur": "Tottenham",
    "Westham United": "Westham",
    "Wolverhampton Wanderers": "Wolves"
}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged
# Out:
#      actual_x  prediction_x       date                   team_x  \
# 0           0             0 2022-01-23                  Arsenal
# 1           1             1 2022-02-10                  Arsenal
# 2           1             0 2022-02-19                  Arsenal
# 3           1             1 2022-02-24                  Arsenal
# 4           1             1 2022-03-06                  Arsenal
# ..        ...           ...        ...                      ...
# 244         1             0 2022-03-13  Wolverhampton Wanderers
# 245         0             0 2022-03-18  Wolverhampton Wanderers
# 246         1             0 2022-04-02  Wolverhampton Wanderers
# 247         0             0 2022-04-08  Wolverhampton Wanderers
# 248         0             0 2022-04-24  Wolverhampton Wanderers
#
#         opponent_x result_x new_team_x  actual_y  prediction_y  \
# 0          Burnley        D    Arsenal         0             0
# 1           Wolves        W    Arsenal         0             0
# 2        Brentford        W    Arsenal         0             0
# 3           Wolves        W    Arsenal         0             0
# 4          Watford        W    Arsenal         0             0
# ..             ...      ...        ...       ...           ...
# 244        Everton        W     Wolves         0             0
# 245   Leeds United        L     Wolves         1             0
# 246    Aston Villa        W     Wolves         0             0
# 247  Newcastle Utd        L     Wolves         1             0
# 248        Burnley        L     Wolves         1             0
#
#                       team_y opponent_y result_y     new_team_y
# 0                    Burnley    Arsenal        D        Burnley
# 1    Wolverhampton Wanderers    Arsenal        L         Wolves
# 2                  Brentford    Arsenal        L      Brentford
# 3    Wolverhampton Wanderers    Arsenal        L         Wolves
# 4                    Watford    Arsenal        L        Watford
# ..                       ...        ...      ...            ...
# 244                  Everton     Wolves        L        Everton
# 245             Leeds United     Wolves        W   Leeds United
# 246              Aston Villa     Wolves        L    Aston Villa
# 247         Newcastle United     Wolves        W  Newcastle Utd
# 248                  Burnley     Wolves        W        Burnley
#
# [249 rows x 13 columns]

# %%
merged[(merged["prediction_x"] ==1) & (merged["prediction_y"] == 0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    26
# 0    13
# Name: count, dtype: int64

# %%
26/39
# Out:
# 0.6666666666666666
